# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %%
box = pd. read_table("../grain_bound_sims/md.10000.dump", skiprows=8,
                     delimiter=" ")
box.head()
# Out:
#    type  id   q  mass         x         y         z        vx       vy  \
# 0     1   1  10    20  0.001594  0.001272  0.003118 -193.4000  10.0564
# 1     1   2  10    20  0.001727  0.003413  0.000121   18.6455  29.3714
# 2     1   3  10    20  0.004190  0.003435  0.000900   63.3823 -20.3185
# 3     1   4  10    20  0.002370  0.000467  0.000708 -113.1680  47.1195
# 4     1   5  10    20  0.001840  0.002414  0.003490  105.6320 -89.4834
#
#          vz  ix  iy  iz
# 0 -111.5500  -2   3  -6
# 1   -3.6926   0   2  -4
# 2   60.9897  -1  -2   2
# 3  -61.4779   1   0   0
# 4  -90.4939   1  -1  -2

# %%
names = ["id", "atoms", "charge", "x", "y", "z"]
box = pd. read_table("../grain_bound_sims/grainBoundBcc.dat", skiprows=15,
                     delim_whitespace=True, names = names)
box.head()
# Out:
# /tmp/ipykernel_8529/2650470883.py:2: FutureWarning:
#
# The 'delim_whitespace' keyword in pd.read_table is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#    id  atoms  charge           x         y           z
# 0   1      1     9.2   22.292374  7.135655  310.270027
# 1   2      1     9.2   52.605811  7.135655  310.270027
# 2   3      1     9.2   82.919248  7.135655  310.270027
# 3   4      1     9.2  113.232685  7.135655  310.270027
# 4   5      1     9.2  143.546122  7.135655  310.270027

# %%
fig = px.scatter_3d(box, x="x", y='y', z='z')
fig.update_traces(marker=dict(size=3))
fig.show()
